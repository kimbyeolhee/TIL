# %% [markdown]
# 1. **import**: 필요한 모듈 import
# 2. **전처리**: 학습에 필요한 데이터 전처리를 수행
# 3. **모델링(model)**: 모델을 정의
# 4. **컴파일(compile)**: 모델을 생성
# 5. **학습 (fit)**: 모델을 학습

# %% [markdown]
# # import

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

# %% [markdown]
# # 전처리

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([5.0, 6.0, 7.0, 8.0, 9.0, 10.0], dtype=float)

# %% [markdown]
# # 모델 정의

# %% [markdown]
# 반드시, 첫번째 layer에는 input_shape을 지정해 주어야 함

# %%
model = Sequential([
                    Dense(1, input_shape=(1,))
])

# %% [markdown]
# # 모델 생성 (Compile)

# %% [markdown]
# 적절한 optimizer과 loss 선정
# * optimizer : 'sgd(Stochastic Gradient Descent)'
# * loss : mse

# %%
model.compile(optimizer='sgd', loss='mse')

# %% [markdown]
# # 학습 (fit)

# %%
model.fit(xs, ys, epochs=1200, verbose=0)

# %% [markdown]
# # 예측 (Predict)

# %%
model.predict([10.0])
# Out:
# array([[16.00005]], dtype=float32)

# %% [markdown]
# # Review

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

# data
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([5.0, 6.0, 7.0, 8.0, 9.0, 10.0], dtype=float)

# model definition
model = Sequential([
                  Dense(1, input_shape=(1,))
])

# compile
model.compile(optimizer='sgd', loss='mse')

# fit
model.fit(xs, ys, epochs=1200, verbose=0)

# predict
model.predict([10.0])
# Out:
# array([[16.000046]], dtype=float32)
